# %%
print(int(3.5))
print(6/2)
print(8//2)
print("hello" == "world")
print(str("123-456-7990"))
print(float(177.56))
# Out:
# 3
# 3.0
# 4
# False
# 123-456-7990
# 177.56

# %% [markdown]
# ## **Adding numbers/strings**

# %%
a=3
b=5
c=a+b
print(a,"+",b,"->",c)
d = "archit"
e = " singh"
r = d + e
print (r)
# Out:
# 3 + 5 -> 8
# archit singh

# %% [markdown]
# ## User Input

# %%
a = input("Enter First: ")
b = input("Enter Second: ")
c = a + b
print  (a, " + ",b,"-> ", c)
# Out:
# Enter First: comp
# Enter Second: app
# comp  +  app ->  compapp

# %% [markdown]
# ## **Loops**

# %% [markdown]
# ### While

# %%
print("while")
i = 1
while i<=10:
  print(i*i)
  i=i+2
# Out:
# while
# 1
# 9
# 25
# 49
# 81

# %% [markdown]
# ### For

# %%
print("for")
for i in range(0,11,1):
  print(i*i*i)
# Out:
# for
# 0
# 1
# 8
# 27
# 64
# 125
# 216
# 343
# 512
# 729
# 1000

# %% [markdown]
# ### Factorial

# %%
print("factorial")
a = 10
ans=1
for i in range (1,10):
  ans=ans*i
print(ans)
# Out:
# factorial
# 362880

# %% [markdown]
# ## **Conditionals**

# %%
n = int(input("enter num:"))
if n%2 == 0:
	print (n,"is even")
else:
	print (n,"is odd")
# Out:
# enter num:786
# 786 is even

# %% [markdown]
# ### Prime check

# %%
n = int(input("enter number:"))

for i in range (2,n//2):
  if n%i == 0:
      print("Not Prime")
      break
# Out:
# enter number:766
# Not Prime

# %% [markdown]
# ## **Functions**

# %%
def isPrime(n):
    if n < 2:
        return False

    for i in range(2, n):
        if n % i == 0:
            return False

    return True

num = int(input("Enter a number: "))

if isPrime(num):
    print(num, "is Prime")
else:
    print(num, "is Not Prime")
# Out:
# Enter a number: 765
# 765 is Not Prime

# %% [markdown]
# ## **Random Numbers**

# %%
import random
import string

password = "".join(random.sample(string.ascii_letters + string.digits, 8))

print("roll No:", 1024170124)
print(" password", password)
# Out:
# roll No: 1024170124
#  password D3CiVS1G

# %% [markdown]
# ## **Exception Handling**

# %%
try:
    file = input("Enter file name: ")
    fp = open(file)
    print(fp.read())
    fp.close()
except:
    print("file not found")
# Out:
# Enter file name: trp
# file not found

# %% [markdown]
# ## **Dictionary**

# %%
student = {
    "name":"archit",
    "roll":1024170124,
    "branch":"cse"
}
student["semester"] = 5
for key in student:
    print(key,":",student[key])
# Out:
# name : archit
# roll : 1024170124
# branch : cse
# semester : 5

# %% [markdown]
# ## **Tuple**

# %%
details = ("archit", 1024170124, "cse")

print(details)

temp = list(details)
temp.append("assignment")
details = tuple(temp)
print(details)
# Out:
# ('archit', 1024170124, 'cse')
# ('archit', 1024170124, 'cse', 'assignment')

# %% [markdown]
# ## **File handling**

# %%
fp = open("me.txt", "w")

fp.write("name archit   ")
fp.write("roll:1024170124   ")
fp.write("branch:cse   ")

fp.close()

fp = open("me.txt")

for line in fp:
    print(line.strip())

fp.close()
# Out:
# name archit   roll:1024170124   branch:cse
